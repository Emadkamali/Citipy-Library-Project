# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 575

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | olonkinbyen
# Processing Record 2 of Set 1 | gaogou
# Processing Record 3 of Set 1 | sola
# Processing Record 4 of Set 1 | udachny
# Processing Record 5 of Set 1 | saipan
# Processing Record 6 of Set 1 | mahina
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | timmins
# Processing Record 9 of Set 1 | bilibino
# Processing Record 10 of Set 1 | wailua homesteads
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | belmonte
# Processing Record 13 of Set 1 | la passe
# Processing Record 14 of Set 1 | morris
# Processing Record 15 of Set 1 | padampur
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | tura
# Processing Record 18 of Set 1 | bethel
# Processing Record 19 of Set 1 | adamstown
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | coquimbo
# Processing Record 22 of Set 1 | puyang chengguanzhen
# Processing Record 23 of Set 1 | longyearbyen
# Processing Record 24 of Set 1 | dryden
# Processing Record 25 of Set 1 | port-aux-francais
# Processing Record 26 of Set 1 | ishigaki
# Processing Record 27 of Set 1 | ilulissat
# Processing Record 28 of Set 1 | yuzhno-kurilsk
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | blackmans bay
# Processing Record 31 of Set 1 | hammerfest
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | bogale
# Processing Record 34 of Set 1 | zaozersk
# Processing Record 35 of Set 1 | yanbu
# Processing Record 36 of Set 1 | mata-utu
# Processing Record 37 of Set 1 | edinburgh of the seven seas
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | strezhevoy
# Processing Record 40 of Set 1 | lodja
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | chonchi
# Processing Record 43 of Set 1 | broome
# Processing Record 44 of Set 1 | villa gesell
# Processing Record 45 of Set 1 | sitka
# Processing Record 46 of Set 1 | margaret river
# Processing Record 47 of Set 1 | iskateley
# Processing Record 48 of Set 1 | east ballina
# Processing Record 49 of Set 1 | hadibu
# Processing Record 50 of Set 1 | puerto natales
# Processing Record 0 of Set 2 | iqaluit
# Processing Record 1 of Set 2 | maubara
# City not found. Skipping...
# Processing Record 2 of Set 2 | saldanha
# Processing Record 3 of Set 2 | talakan
# Processing Record 4 of Set 2 | west island
# Processing Record 5 of Set 2 | quelimane
# Processing Record 6 of Set 2 | cornillon
# Processing Record 7 of Set 2 | port mathurin
# Processing Record 8 of Set 2 | kupino
# Processing Record 9 of Set 2 | urangan
# Processing Record 10 of Set 2 | college
# Processing Record 11 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 12 of Set 2 | hami
# Processing Record 13 of Set 2 | berdigestyakh
# Processing Record 14 of Set 2 | recani
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | catemaco
# Processing Record 17 of Set 2 | isafjordur
# Processing Record 18 of Set 2 | homer
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | nova sintra
# Processing Record 21 of Set 2 | san antonio de pale
# Processing Record 22 of Set 2 | redencao
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | kristiansund
# Processing Record 26 of Set 2 | terenos
# Processing Record 27 of Set 2 | waitangi
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | galesong
# Processing Record 31 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 32 of Set 2 | tyukhtet
# Processing Record 33 of Set 2 | stanley
# Processing Record 34 of Set 2 | panambi
# Processing Record 35 of Set 2 | lazaro cardenas
# Processing Record 36 of Set 2 | whitehorse
# Processing Record 37 of Set 2 | tomatlan
# Processing Record 38 of Set 2 | santanyi
# Processing Record 39 of Set 2 | papatowai
# Processing Record 40 of Set 2 | ketchikan
# Processing Record 41 of Set 2 | badger
# Processing Record 42 of Set 2 | almonte
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | howrah
# Processing Record 45 of Set 2 | ar rass
# Processing Record 46 of Set 2 | morehead city
# Processing Record 47 of Set 2 | gonzales
# Processing Record 48 of Set 2 | la gi
# Processing Record 49 of Set 2 | khost
# Processing Record 0 of Set 3 | sisimiut
# Processing Record 1 of Set 3 | jamestown
# Processing Record 2 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 3 of Set 3 | amga
# Processing Record 4 of Set 3 | weno
# Processing Record 5 of Set 3 | lira
# Processing Record 6 of Set 3 | minas de marcona
# Processing Record 7 of Set 3 | hoopstad
# Processing Record 8 of Set 3 | kindu
# Processing Record 9 of Set 3 | asifabad
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | dul'durga
# Processing Record 12 of Set 3 | dalbandin
# Processing Record 13 of Set 3 | fort st. john
# Processing Record 14 of Set 3 | sinop
# Processing Record 15 of Set 3 | uturoa
# Processing Record 16 of Set 3 | yeosu
# Processing Record 17 of Set 3 | shingu
# Processing Record 18 of Set 3 | vorgashor
# Processing Record 19 of Set 3 | okhotsk
# Processing Record 20 of Set 3 | klyuchi
# Processing Record 21 of Set 3 | olinda
# Processing Record 22 of Set 3 | castillos
# Processing Record 23 of Set 3 | aginskoye
# Processing Record 24 of Set 3 | vila franca do campo
# Processing Record 25 of Set 3 | igarka
# Processing Record 26 of Set 3 | kittila
# Processing Record 27 of Set 3 | mungwi
# Processing Record 28 of Set 3 | sao gabriel da cachoeira
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | torghay
# Processing Record 31 of Set 3 | kathu
# Processing Record 32 of Set 3 | mastic beach
# Processing Record 33 of Set 3 | vozdvizhenka
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | nurota
# Processing Record 36 of Set 3 | st. john's
# Processing Record 37 of Set 3 | atafu village
# Processing Record 38 of Set 3 | midvagur
# Processing Record 39 of Set 3 | tari
# Processing Record 40 of Set 3 | prince rupert
# Processing Record 41 of Set 3 | poptun
# Processing Record 42 of Set 3 | lata
# Processing Record 43 of Set 3 | bikenibeu village
# Processing Record 44 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 45 of Set 3 | farmville
# Processing Record 46 of Set 3 | riyadh
# Processing Record 47 of Set 3 | welby
# Processing Record 48 of Set 3 | onega
# Processing Record 49 of Set 3 | caleta de carquin
# Processing Record 0 of Set 4 | vilyuchinsk
# Processing Record 1 of Set 4 | iskushuban
# Processing Record 2 of Set 4 | guaruja
# Processing Record 3 of Set 4 | cromer
# Processing Record 4 of Set 4 | la sarre
# Processing Record 5 of Set 4 | ust-nera
# Processing Record 6 of Set 4 | cruzeiro do sul
# Processing Record 7 of Set 4 | wotho
# Processing Record 8 of Set 4 | dahab
# Processing Record 9 of Set 4 | korla
# Processing Record 10 of Set 4 | beaumont
# Processing Record 11 of Set 4 | brisas de zicatela
# Processing Record 12 of Set 4 | akim oda
# Processing Record 13 of Set 4 | invercargill
# Processing Record 14 of Set 4 | mao
# Processing Record 15 of Set 4 | hermanus
# Processing Record 16 of Set 4 | anadyr
# Processing Record 17 of Set 4 | jiagedaqi
# Processing Record 18 of Set 4 | susuman
# Processing Record 19 of Set 4 | fereydun kenar
# Processing Record 20 of Set 4 | qo'qon
# City not found. Skipping...
# Processing Record 21 of Set 4 | acarau
# Processing Record 22 of Set 4 | cruz grande
# Processing Record 23 of Set 4 | wakkanai
# Processing Record 24 of Set 4 | tazovsky
# Processing Record 25 of Set 4 | mazamari
# Processing Record 26 of Set 4 | libreville
# Processing Record 27 of Set 4 | guerrero negro
# Processing Record 28 of Set 4 | sena madureira
# Processing Record 29 of Set 4 | princeville
# Processing Record 30 of Set 4 | ancud
# Processing Record 31 of Set 4 | dingli
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | san julian
# Processing Record 34 of Set 4 | mount pearl
# Processing Record 35 of Set 4 | fonadhoo
# City not found. Skipping...
# Processing Record 36 of Set 4 | nagqu
# Processing Record 37 of Set 4 | kourou
# Processing Record 38 of Set 4 | renfrew
# Processing Record 39 of Set 4 | arno
# Processing Record 40 of Set 4 | mogadishu
# Processing Record 41 of Set 4 | dudinka
# Processing Record 42 of Set 4 | lebu
# Processing Record 43 of Set 4 | presidente medici
# Processing Record 44 of Set 4 | es castell
# Processing Record 45 of Set 4 | keflavik
# Processing Record 46 of Set 4 | kamina
# Processing Record 47 of Set 4 | nyurba
# Processing Record 48 of Set 4 | muroto-misakicho
# Processing Record 49 of Set 4 | gamba
# Processing Record 0 of Set 5 | tobruk
# Processing Record 1 of Set 5 | abadan
# Processing Record 2 of Set 5 | necochea
# Processing Record 3 of Set 5 | portland
# Processing Record 4 of Set 5 | dongsheng
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | alice springs
# Processing Record 7 of Set 5 | honmachi
# Processing Record 8 of Set 5 | cuatro cienegas de carranza
# Processing Record 9 of Set 5 | megion
# Processing Record 10 of Set 5 | labrador city
# Processing Record 11 of Set 5 | snovsk
# Processing Record 12 of Set 5 | ordos
# City not found. Skipping...
# Processing Record 13 of Set 5 | vadso
# Processing Record 14 of Set 5 | sur
# Processing Record 15 of Set 5 | beau vallon
# Processing Record 16 of Set 5 | wismar
# Processing Record 17 of Set 5 | rabaul
# Processing Record 18 of Set 5 | rajin
# Processing Record 19 of Set 5 | fort mcmurray
# Processing Record 20 of Set 5 | howard springs
# Processing Record 21 of Set 5 | kingston
# Processing Record 22 of Set 5 | envira
# Processing Record 23 of Set 5 | kirakira
# Processing Record 24 of Set 5 | melfort
# Processing Record 25 of Set 5 | motueka
# Processing Record 26 of Set 5 | port-gentil
# Processing Record 27 of Set 5 | lihue
# Processing Record 28 of Set 5 | hinton
# Processing Record 29 of Set 5 | port isabel
# Processing Record 30 of Set 5 | tupiza
# Processing Record 31 of Set 5 | apac
# Processing Record 32 of Set 5 | al qusayr
# Processing Record 33 of Set 5 | lincheng
# Processing Record 34 of Set 5 | ambon
# Processing Record 35 of Set 5 | farafangana
# Processing Record 36 of Set 5 | antsiranana
# Processing Record 37 of Set 5 | nar'yan-mar
# Processing Record 38 of Set 5 | tanki leendert
# City not found. Skipping...
# Processing Record 39 of Set 5 | khanty-mansiysk
# Processing Record 40 of Set 5 | nushki
# Processing Record 41 of Set 5 | sandnessjoen
# Processing Record 42 of Set 5 | utrik
# Processing Record 43 of Set 5 | constantia
# Processing Record 44 of Set 5 | urucara
# Processing Record 45 of Set 5 | rosso
# Processing Record 46 of Set 5 | cancun
# Processing Record 47 of Set 5 | fortuna
# Processing Record 48 of Set 5 | ulladulla
# Processing Record 49 of Set 5 | mitu
# Processing Record 0 of Set 6 | albu kamal
# Processing Record 1 of Set 6 | urk
# Processing Record 2 of Set 6 | puerto maldonado
# Processing Record 3 of Set 6 | alaghsas
# Processing Record 4 of Set 6 | ebon
# Processing Record 5 of Set 6 | jincheng
# Processing Record 6 of Set 6 | kailua-kona
# Processing Record 7 of Set 6 | swakopmund
# Processing Record 8 of Set 6 | nuuk
# Processing Record 9 of Set 6 | mount gambier
# Processing Record 10 of Set 6 | ugoofaaru
# Processing Record 11 of Set 6 | obihiro
# Processing Record 12 of Set 6 | hawaiian paradise park
# Processing Record 13 of Set 6 | jinchang
# Processing Record 14 of Set 6 | saratamata
# City not found. Skipping...
# Processing Record 15 of Set 6 | nadi
# Processing Record 16 of Set 6 | harstad
# Processing Record 17 of Set 6 | carnarvon
# Processing Record 18 of Set 6 | enewetak
# Processing Record 19 of Set 6 | lubuklinggau
# Processing Record 20 of Set 6 | qamdo
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | smach mean chey
# City not found. Skipping...
# Processing Record 23 of Set 6 | kampong cham
# Processing Record 24 of Set 6 | artova
# Processing Record 25 of Set 6 | thunder bay
# Processing Record 26 of Set 6 | igrim
# Processing Record 27 of Set 6 | albemarle
# Processing Record 28 of Set 6 | kodiak
# Processing Record 29 of Set 6 | lubang
# Processing Record 30 of Set 6 | anloga
# Processing Record 31 of Set 6 | kavaratti
# Processing Record 32 of Set 6 | ust-tsilma
# Processing Record 33 of Set 6 | madalena
# Processing Record 34 of Set 6 | nam dinh
# Processing Record 35 of Set 6 | bayan nur
# City not found. Skipping...
# Processing Record 36 of Set 6 | gadzhiyevo
# Processing Record 37 of Set 6 | biograd na moru
# Processing Record 38 of Set 6 | usinsk
# Processing Record 39 of Set 6 | mukalla
# Processing Record 40 of Set 6 | ivdel'
# Processing Record 41 of Set 6 | kattivakkam
# Processing Record 42 of Set 6 | la foa
# Processing Record 43 of Set 6 | wernigerode
# Processing Record 44 of Set 6 | moyale
# Processing Record 45 of Set 6 | santa ana
# Processing Record 46 of Set 6 | puerto armuelles
# Processing Record 47 of Set 6 | mana
# Processing Record 48 of Set 6 | yulinshi
# Processing Record 49 of Set 6 | sosnovo-ozerskoye
# Processing Record 0 of Set 7 | fountain inn
# Processing Record 1 of Set 7 | east end
# Processing Record 2 of Set 7 | spring creek
# Processing Record 3 of Set 7 | magadan
# Processing Record 4 of Set 7 | kunszentmarton
# Processing Record 5 of Set 7 | kuta
# Processing Record 6 of Set 7 | santa rosa de viterbo
# Processing Record 7 of Set 7 | novodvinsk
# Processing Record 8 of Set 7 | monrovia
# Processing Record 9 of Set 7 | dunedin
# Processing Record 10 of Set 7 | minab
# Processing Record 11 of Set 7 | port saint john's
# Processing Record 12 of Set 7 | dipayal
# Processing Record 13 of Set 7 | hwange
# Processing Record 14 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 15 of Set 7 | noumea
# Processing Record 16 of Set 7 | kidal
# Processing Record 17 of Set 7 | port douglas
# Processing Record 18 of Set 7 | rongelap
# Processing Record 19 of Set 7 | belo sur tsiribihina
# Processing Record 20 of Set 7 | mejit
# Processing Record 21 of Set 7 | khorugh
# Processing Record 22 of Set 7 | dalnegorsk
# Processing Record 23 of Set 7 | taoudenni
# Processing Record 24 of Set 7 | tazacorte
# Processing Record 25 of Set 7 | bodo
# Processing Record 26 of Set 7 | huarmey
# Processing Record 27 of Set 7 | palangkaraya
# Processing Record 28 of Set 7 | sanchazi
# Processing Record 29 of Set 7 | codrington
# Processing Record 30 of Set 7 | paros
# Processing Record 31 of Set 7 | flying fish cove
# Processing Record 32 of Set 7 | greenville
# Processing Record 33 of Set 7 | yemva
# Processing Record 34 of Set 7 | nikolayevsk-on-amure
# Processing Record 35 of Set 7 | zanjan
# Processing Record 36 of Set 7 | qobustan
# Processing Record 37 of Set 7 | laguna
# Processing Record 38 of Set 7 | labytnangi
# Processing Record 39 of Set 7 | morton
# Processing Record 40 of Set 7 | purpe
# Processing Record 41 of Set 7 | tromso
# Processing Record 42 of Set 7 | cooper's town
# Processing Record 43 of Set 7 | suva
# Processing Record 44 of Set 7 | ialibu
# Processing Record 45 of Set 7 | atmakur
# Processing Record 46 of Set 7 | lagoa
# Processing Record 47 of Set 7 | ngereklmadel
# Processing Record 48 of Set 7 | saint-pierre
# Processing Record 49 of Set 7 | salinopolis
# Processing Record 0 of Set 8 | boda
# Processing Record 1 of Set 8 | tommot
# Processing Record 2 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 3 of Set 8 | sungai raya
# Processing Record 4 of Set 8 | mulanje
# Processing Record 5 of Set 8 | tamanrasset
# Processing Record 6 of Set 8 | shanwei
# Processing Record 7 of Set 8 | la'ie
# Processing Record 8 of Set 8 | la asuncion
# Processing Record 9 of Set 8 | port lincoln
# Processing Record 10 of Set 8 | bom jesus
# Processing Record 11 of Set 8 | madang
# Processing Record 12 of Set 8 | rio grande
# Processing Record 13 of Set 8 | undurkhaan
# Processing Record 14 of Set 8 | hasaki
# Processing Record 15 of Set 8 | lagos
# Processing Record 16 of Set 8 | jining
# Processing Record 17 of Set 8 | metlili chaamba
# Processing Record 18 of Set 8 | kirensk
# Processing Record 19 of Set 8 | sol'-iletsk
# Processing Record 20 of Set 8 | yaren
# Processing Record 21 of Set 8 | mo i rana
# Processing Record 22 of Set 8 | aioun
# Processing Record 23 of Set 8 | lerwick
# Processing Record 24 of Set 8 | ganjam
# Processing Record 25 of Set 8 | santa elena de uairen
# Processing Record 26 of Set 8 | prigen
# Processing Record 27 of Set 8 | we
# City not found. Skipping...
# Processing Record 28 of Set 8 | cockburn town
# Processing Record 29 of Set 8 | el granada
# Processing Record 30 of Set 8 | tan-tan
# Processing Record 31 of Set 8 | urraween
# Processing Record 32 of Set 8 | dawei
# Processing Record 33 of Set 8 | kontcha
# Processing Record 34 of Set 8 | fort bragg
# Processing Record 35 of Set 8 | izhmorskiy
# Processing Record 36 of Set 8 | kapuskasing
# Processing Record 37 of Set 8 | tolanaro
# Processing Record 38 of Set 8 | kuruman
# Processing Record 39 of Set 8 | toga village
# City not found. Skipping...
# Processing Record 40 of Set 8 | mhamid
# Processing Record 41 of Set 8 | baley
# Processing Record 42 of Set 8 | touros
# Processing Record 43 of Set 8 | valparaiso
# Processing Record 44 of Set 8 | n'dalatando
# Processing Record 45 of Set 8 | sampit
# Processing Record 46 of Set 8 | ascencion de guarayos
# City not found. Skipping...
# Processing Record 47 of Set 8 | soio
# Processing Record 48 of Set 8 | loreto
# Processing Record 49 of Set 8 | prymors'k
# Processing Record 0 of Set 9 | altai
# Processing Record 1 of Set 9 | bani walid
# Processing Record 2 of Set 9 | ponta delgada
# Processing Record 3 of Set 9 | aleksandrovsk-sakhalinskiy
# Processing Record 4 of Set 9 | hotan
# Processing Record 5 of Set 9 | port hedland
# Processing Record 6 of Set 9 | eirunepe
# Processing Record 7 of Set 9 | meulaboh
# Processing Record 8 of Set 9 | kletskaya
# Processing Record 9 of Set 9 | pilas
# Processing Record 10 of Set 9 | khandyga
# Processing Record 11 of Set 9 | den burg
# Processing Record 12 of Set 9 | jakarta
# Processing Record 13 of Set 9 | callao
# Processing Record 14 of Set 9 | kanniyakumari
# Processing Record 15 of Set 9 | regina
# Processing Record 16 of Set 9 | vatra dornei
# Processing Record 17 of Set 9 | boca do acre
# Processing Record 18 of Set 9 | kartal
# Processing Record 19 of Set 9 | south hedland
# Processing Record 20 of Set 9 | gaspe
# Processing Record 21 of Set 9 | zhanga buqtyrma
# Processing Record 22 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 23 of Set 9 | bayanhongor
# Processing Record 24 of Set 9 | trujillo
# Processing Record 25 of Set 9 | tanjungbalai
# Processing Record 26 of Set 9 | dapa
# Processing Record 27 of Set 9 | belabo
# Processing Record 28 of Set 9 | n'zeto
# Processing Record 29 of Set 9 | gulf breeze
# Processing Record 30 of Set 9 | puerto aysen
# Processing Record 31 of Set 9 | mul
# Processing Record 32 of Set 9 | akureyri
# Processing Record 33 of Set 9 | kiunga
# Processing Record 34 of Set 9 | topeka
# Processing Record 35 of Set 9 | mont-dore
# Processing Record 36 of Set 9 | livingstone
# Processing Record 37 of Set 9 | walvis bay
# Processing Record 38 of Set 9 | cabo san lucas
# Processing Record 39 of Set 9 | naze
# Processing Record 40 of Set 9 | morant bay
# Processing Record 41 of Set 9 | tweed heads
# Processing Record 42 of Set 9 | kasama
# Processing Record 43 of Set 9 | san luis de la loma
# Processing Record 44 of Set 9 | crucecita
# Processing Record 45 of Set 9 | boa vista
# Processing Record 46 of Set 9 | santa terezinha
# Processing Record 47 of Set 9 | mugia
# Processing Record 48 of Set 9 | guadalajara
# Processing Record 49 of Set 9 | kill devil hills
# Processing Record 0 of Set 10 | wynyard
# Processing Record 1 of Set 10 | bardai
# Processing Record 2 of Set 10 | pirai do sul
# Processing Record 3 of Set 10 | ormond-by-the-sea
# Processing Record 4 of Set 10 | sao jose de ribamar
# Processing Record 5 of Set 10 | nago
# Processing Record 6 of Set 10 | bom jesus da lapa
# Processing Record 7 of Set 10 | bodaybo
# Processing Record 8 of Set 10 | zelenogorskiy
# Processing Record 9 of Set 10 | newman
# Processing Record 10 of Set 10 | yoro
# Processing Record 11 of Set 10 | sinabang
# Processing Record 12 of Set 10 | toamasina
# Processing Record 13 of Set 10 | malango
# Processing Record 14 of Set 10 | waiuku
# Processing Record 15 of Set 10 | remire-montjoly
# Processing Record 16 of Set 10 | ola
# Processing Record 17 of Set 10 | el sauce
# Processing Record 18 of Set 10 | praia da vitoria
# Processing Record 19 of Set 10 | xiaoweizhai
# Processing Record 20 of Set 10 | dien bien phu
# Processing Record 21 of Set 10 | markovo
# Processing Record 22 of Set 10 | bargara
# City not found. Skipping...
# Processing Record 23 of Set 10 | dawesville
# Processing Record 24 of Set 10 | coxen hole
# Processing Record 25 of Set 10 | lorengau
# Processing Record 26 of Set 10 | al ghayzah
# Processing Record 27 of Set 10 | kenora
# Processing Record 28 of Set 10 | ratnagiri
# Processing Record 29 of Set 10 | pangai
# Processing Record 30 of Set 10 | heihe
# Processing Record 31 of Set 10 | ta`u
# Processing Record 32 of Set 10 | bullhead city
# Processing Record 33 of Set 10 | yakeshi
# Processing Record 34 of Set 10 | maba
# Processing Record 35 of Set 10 | east london
# Processing Record 36 of Set 10 | chos malal
# Processing Record 37 of Set 10 | pekan
# Processing Record 38 of Set 10 | palmas
# Processing Record 39 of Set 10 | sechura
# Processing Record 40 of Set 10 | eksjo
# City not found. Skipping...
# Processing Record 41 of Set 10 | dickinson
# Processing Record 42 of Set 10 | port-vila
# Processing Record 43 of Set 10 | luchegorsk
# Processing Record 44 of Set 10 | priozersk
# Processing Record 45 of Set 10 | driefontein
# Processing Record 46 of Set 10 | maun
# Processing Record 47 of Set 10 | aasiaat
# Processing Record 48 of Set 10 | canyon
# Processing Record 49 of Set 10 | kapa'a
# Processing Record 0 of Set 11 | el sauzal de rodriguez
# Processing Record 1 of Set 11 | turbo
# Processing Record 2 of Set 11 | crane
# Processing Record 3 of Set 11 | amungan
# Processing Record 4 of Set 11 | egilsstadir
# Processing Record 5 of Set 11 | isla mujeres
# Processing Record 6 of Set 11 | cartagena del chaira
# Processing Record 7 of Set 11 | yeppoon
# Processing Record 8 of Set 11 | ujae
# Processing Record 9 of Set 11 | bria
# Processing Record 10 of Set 11 | san patricio
# Processing Record 11 of Set 11 | masterton
# Processing Record 12 of Set 11 | houmt el souk
# Processing Record 13 of Set 11 | holualoa
# Processing Record 14 of Set 11 | amaliada
# Processing Record 15 of Set 11 | isna
# Processing Record 16 of Set 11 | aleksandrov gay
# Processing Record 17 of Set 11 | fortuna foothills
# Processing Record 18 of Set 11 | zuni pueblo
# Processing Record 19 of Set 11 | kolyshley
# Processing Record 20 of Set 11 | denmead
# Processing Record 21 of Set 11 | eyl
# Processing Record 22 of Set 11 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 23 of Set 11 | lakatoro
# Processing Record 24 of Set 11 | lospalos
# Processing Record 25 of Set 11 | vryburg
# Processing Record 26 of Set 11 | villa emilio carranza
# Processing Record 27 of Set 11 | severo-yeniseyskiy
# Processing Record 28 of Set 11 | quang ngai
# Processing Record 29 of Set 11 | muisne
# Processing Record 30 of Set 11 | markala
# Processing Record 31 of Set 11 | mount isa
# Processing Record 32 of Set 11 | serowe
# Processing Record 33 of Set 11 | chui
# Processing Record 34 of Set 11 | ruovesi
# Processing Record 35 of Set 11 | muynoq
# Processing Record 36 of Set 11 | altay
# Processing Record 37 of Set 11 | garoua boulai
# Processing Record 38 of Set 11 | waddan
# Processing Record 39 of Set 11 | vurnary
# Processing Record 40 of Set 11 | okha
# Processing Record 41 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 42 of Set 11 | totness
# Processing Record 43 of Set 11 | yudong
# Processing Record 44 of Set 11 | koulikoro
# Processing Record 45 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 46 of Set 11 | quiberon
# Processing Record 47 of Set 11 | saint-joseph
# Processing Record 48 of Set 11 | adh dhibiyah
# City not found. Skipping...
# Processing Record 49 of Set 11 | patacamaya
# Processing Record 0 of Set 12 | queenstown
# Processing Record 1 of Set 12 | tutoia
# Processing Record 2 of Set 12 | viedma
# Processing Record 3 of Set 12 | sorong
# Processing Record 4 of Set 12 | pearsall
# Processing Record 5 of Set 12 | muntok
# Processing Record 6 of Set 12 | airdrie
# Processing Record 7 of Set 12 | santana
# Processing Record 8 of Set 12 | pangody
# Processing Record 9 of Set 12 | plastun
# Processing Record 10 of Set 12 | mananjary
# Processing Record 11 of Set 12 | filingue
# Processing Record 12 of Set 12 | nacozari de garcia
# Processing Record 13 of Set 12 | port sudan
# Processing Record 14 of Set 12 | lovisa
# Processing Record 15 of Set 12 | sho'rchi
# Processing Record 16 of Set 12 | arraial do cabo
# Processing Record 17 of Set 12 | cadale
# Processing Record 18 of Set 12 | conception bay south
# Processing Record 19 of Set 12 | al bawiti
# Processing Record 20 of Set 12 | richards bay
# Processing Record 21 of Set 12 | eldama ravine
# Processing Record 22 of Set 12 | surskoye
# Processing Record 23 of Set 12 | camayenne
# Processing Record 24 of Set 12 | capitan bado
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          552
# Lat           552
# Lng           552
# Max Temp      552
# Humidity      552
# Cloudiness    552
# Wind Speed    552
# Country       552
# Date          552
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  olonkinbyen  70.9221   -8.7187     -2.42        63         100        5.30
# 1       gaogou  34.0175  119.1886     10.66        58           0        5.22
# 2         sola -13.8833  167.5500     27.96        74         100        6.36
# 3      udachny  66.4167  112.4000    -30.82        97         100        3.10
# 4       saipan  15.1355  145.7010     31.39        55          40        6.69
#
#   Country        Date
# 0      SJ  1707704771
# 1      CN  1707704771
# 2      VU  1707704771
# 3      RU  1707704772
# 4      MP  1707704772

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (2022-10-18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2022-10-18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black")

# Incorporate the other graph properties

plt.title("City Latitude vs. Cloudiness (2022-10-18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed

plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties

plt.title("City Latitude vs. Max Temperature (2022-10-18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression_plot(x, y, xlabel='', ylabel='', title=''):
    slope, intercept, r_value, p_value, std_err = linregress(x, y)
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.text(0.5, 0.9, line_eq, fontsize=12, ha='center', transform=plt.gca().transAxes, color='red')

    regress_values = x * slope + intercept
    
    # Plot scatter plot
    plt.scatter(x, y)

    # Plot regression line
    plt.plot(x, slope*x + intercept, color='red')

    # Add labels and title
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    # print the r value
    print(f'The r-value is: {r_value**2}')
    
    # Show plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]
# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

#linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Latitude', 'Max Temp')
# Scatter plot for latitude vs. maximum temperature in the Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], alpha=0.5, edgecolors='black')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])

# Plot the regression line
plt.plot(northern_hemi_df['Lat'], intercept + slope * northern_hemi_df['Lat'], 'r', label='fitted line')

# Add the equation of the line to the plot
plt.text(0, northern_hemi_df['Max Temp'].max(), f'y = {slope:.2f}x + {intercept:.2f}', color='red')

plt.grid(True)
plt.title("Northern Hemisphere Max Latitude vs. Temperature")
plt.tight_layout()
plt.legend()

# Print the r-value
print(f'The r-value is: {r_value**2}')

# Show plot
plt.show()
# Out:
# The r-value is: 0.7161472181434125

# %%
# Linear regression on Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Max Temp')
# Out:
# The r-value is: 0.4121057168607252

# %% [markdown]
# Discussion about the linear relationship:In the Southern Hemisphere, the linear regression analysis demonstrates a notable negative correlation between latitude and maximum temperature. This implies that as latitude increases (moving southward from the equator), maximum temperatures tend to decrease consistently. Thus, latitude emerges as a significant predictor of maximum temperature variation in the Southern Hemisphere, according to data analytics insights.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.05689741545789608

# %%
# Southern Hemisphere
linear_regression_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.0002808747046324618

# %% [markdown]
# Discussion about the linear relationship: Both the first r-value of 0.0569 and the second r-value of 0.00028 indicate very weak positive correlations. These findings suggest that latitude might not strongly predict maximum temperature variation in the Southern Hemisphere. This implies that other factors beyond latitude may play a more significant role in influencing maximum temperatures. Further exploration of additional variables or a refined analytical approach could provide deeper insights into temperature variations in the Southern Hemisphere.
